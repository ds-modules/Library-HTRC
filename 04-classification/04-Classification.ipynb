# %% [markdown]
# ## Classification
#
# This notebook demonstrates some of the classification tasks that can be accomplished using data retrieved from the HTRC API.
#
# We will be using the `scikit-learn` library to tackle these classification problems.
#
# For these examples, we will be gathering data using the advance search from the Hathi Trust library. To create your training set, determine a search query that will become your labels. Once you search, add the search results to a collection named after your label.
#
# Once you have completed adding to your collection, go to "My Collections" under ____. There you will find a button called "Download Metadata".
#
# You'll download the JSON file associated with your collection and place it in the local directory that you are working in. We've already downloaded the example for you.

# %% [markdown]
# ```python
# import json
# import os
#
# jsonFiles = [file for file in os.listdir('.') if file.find('json') != -1]
#
# txts = []
# for file in jsonFiles:
#     with open(file) as f:
#         data = json.load(f)
#
#     texts = data['gathers']
#     ids = [text['htitem_id'] for text in texts]
#
#     filename = data['title'] + '.txt'
#     txts.append(filename)
#
#     # write each id into txt file
#     with open(filename, 'w') as f:
#         for textid in ids:
#             f.write(textid + '\n')
#
# print("JSON files created")
# ```

# %% [markdown]
# Once this step is complete, you can follow the instructions in the Setup notebook to load the data as needed.
#
# ## Task 1: Genre Classification
#
# In this example, we'll be classifying texts into 3 different genres: Poetry, History, and Science Fiction. JSON files containing the metadata for 500 texts in each genre have been included. We've already downloaded the data for you, but if you use your own data you'd need to run the cell below:

# %% [markdown]
# ```python
# import os
#
# history_output = !htid2rsync --f history.txt | rsync -azv --files-from=- data.sharc.hathitrust.org::features/ history/
# poetry_output = !htid2rsync --f poetry.txt | rsync -azv --files-from=- data.sharc.hathitrust.org::features/ poetry/
# scifi_output = !htid2rsync --f scifi.txt | rsync -azv --files-from=- data.sharc.hathitrust.org::features/ scifi/
# outputs = list([history_output, poetry_output, scifi_output])
# subjects = ['history', 'poetry', 'scifi']
#
# paths = {}
# suffix = '.json.bz2'
# for subject, output in zip(subjects, outputs):
#     folder = subject
#     filePaths = [path for path in output if path.endswith(suffix)]
#     paths[subject] = [os.path.join(folder, path) for path in filePaths]
#     fn = subject + '_paths.txt'
#     with open(fn, 'w') as f:
#         for path in paths[subject]:
#             p = str(path) + '\n'
#             f.write(p)
#
# print("Path extraction complete")
# ```

# %% [markdown]
# As in the previous notebooks, we'll construct `FeatureReader` objects for each corpus. The line below reads in path files we created to the downloaded data:

# %%
from htrc_features import FeatureReader

paths = {}
subjects = ['history', 'poetry', 'scifi']
for subject in subjects:
    with open(subject + '_paths.txt', 'r') as f:
        paths[subject] = [line[:len(line)-1] for line in f.readlines()]
        
history = FeatureReader(paths['history'])

poetry = FeatureReader(paths['poetry'])

scifi = FeatureReader(paths['scifi'])

print("Finished reading paths")
# Out:
# Finished reading paths

# %% [markdown]
# To create our bag of words matrix, we need to keep a global dictionary of all words seen in each of our texts. We initialize "wordDict", which tracks all the words seen and records its index in the bag of words matrix. We also keep a list of volumes so that we can parse them later.

# %%
import numpy as np

wordDict = {}
i = 0 
volumes = []

print("Generating global dictionary")
volCount = 0
for vol in scifi.volumes():
    volumes.append(vol)
    tok_list = vol.tokenlist(pages=False)
    tokens = tok_list.index.get_level_values('token')
    if volCount == 200:  # first 200 from scifi volumes
        break
    volCount += 1 
    
    for token in tokens:
        if token not in wordDict.keys():
            wordDict[token] = i
            i += 1

for vol in poetry.volumes():
    volumes.append(vol)
    tok_list = vol.tokenlist(pages=False)
    tokens = tok_list.index.get_level_values('token')
    if volCount == 400:  # additional 200 from poetry volumes
        break
    volCount += 1 
    
    for token in tokens:
        if token not in wordDict.keys():
            wordDict[token] = i
            i += 1

print("Global dictionary generated")
# Out:
# Generating global dictionary
# Global dictionary generated

# %% [markdown]
# ## Challenge
# How would you change the above code to have 500 training volumes per class?
#
# ---
#
# Once we construct the global dictionary, we can fill the bag of words matrix with the word counts for each volume. Once we have this, we will use it to format the training data for our model.

# %%
print("Generating bag of words matrix")
dtm = np.zeros((volCount, len(wordDict.keys())))

for i, vol in enumerate(volumes):
    tok_list = vol.tokenlist(pages=False)
    counts = list(tok_list['count'])
    tokens = tok_list.index.get_level_values('token')
    
    for token, count in zip(tokens, counts):
        try:
            index = wordDict[token]
            dtm[i, index] = count
        except:
            pass
        
X = dtm
y = np.zeros((400))
y[200:400] = 1

print("Finished")
# Out:
# Generating bag of words matrix
# Finished

# %% [markdown]
# We can then use the `TfidfTransformer` to format the bag of words matrix, so that we can fit it to our LinearSVC model. Let's see how our model does.

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.svm import LinearSVC
from sklearn import cross_validation

tfidf = TfidfTransformer()
out = tfidf.fit_transform(X, y)

model = LinearSVC()

score = cross_validation.cross_val_score(model, X, y, cv=10)
print(np.mean(score))
# Out:
# /Users/chench/anaconda/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 0.8975

# %% [markdown]
# We can also get the most helpful features, or words, for each class. First we'll `fit` the model:

# %%
model.fit(X, y)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
feats = np.argsort(model.coef_[0])[:50]
top_scifi = [(list(feats).index(wordDict[w]) + 1, w) for w in wordDict.keys() if wordDict[w] in feats]
sorted(top_scifi)
# Out:
# [(1, 'w'),
#  (2, 'science'),
#  (3, 'fiction'),
#  (4, 'SF'),
#  (5, '"'),
#  (6, 'Science'),
#  (7, 'Fiction'),
#  (8, 'London'),
#  (9, 'from'),
#  (10, 'at'),
#  (11, 'you'),
#  (12, 'story'),
#  (13, 'it'),
#  (14, 'into'),
#  (15, '?'),
#  (16, 'are'),
#  (17, ':'),
#  (18, 'Earth'),
#  (19, 'But'),
#  (20, 'they'),
#  (21, 'He'),
#  (22, 'stories'),
#  (23, '('),
#  (24, 'space'),
#  (25, 'aliens'),
#  (26, 'an'),
#  (27, 'has'),
#  (28, 'he'),
#  (29, 'I'),
#  (30, 'me'),
#  (31, 'ale'),
#  (32, 'but'),
#  (33, 'two'),
#  (34, 'W'),
#  (35, 'Director'),
#  (36, 'have'),
#  (37, 'lub'),
#  (38, 'za'),
#  (39, 'could'),
#  (40, 'Wells'),
#  (41, 'your'),
#  (42, 'Roberts'),
#  (43, 'ship'),
#  (44, 'fantasy'),
#  (45, 'do'),
#  (46, 'only'),
#  (47, 'time'),
#  (48, 'planet'),
#  (49, 'tak'),
#  (50, 'new')]

# %%
feats = np.argsort(model.coef_[0])[-50:]
top_poetry = [(list(feats).index(wordDict[w]) + 1, w) for w in wordDict.keys() if wordDict[w] in feats]
sorted(top_poetry, key=lambda tup: tup[0])
# Out:
# [(1, 'deal'),
#  (2, 'AND'),
#  (3, 'whole'),
#  (4, '10'),
#  (5, 'Land'),
#  (6, 'America'),
#  (7, 'Master'),
#  (8, 'Columbia'),
#  (9, 'by'),
#  (10, 'after'),
#  (11, 'live'),
#  (12, 'on'),
#  (13, 'rule'),
#  (14, 'On'),
#  (15, 'White'),
#  (16, 'H.'),
#  (17, "'"),
#  (18, 'which'),
#  (19, 'or'),
#  (20, 'country'),
#  (21, "'s"),
#  (22, 'that'),
#  (23, 'this'),
#  (24, 'American'),
#  (25, 'A'),
#  (26, 'not'),
#  (27, 'her'),
#  (28, 'came'),
#  (29, 'poetry'),
#  (30, 'For'),
#  (31, 'By'),
#  (32, 'love'),
#  (33, 'Law'),
#  (34, 'planted'),
#  (35, 'To'),
#  (36, '1'),
#  (37, 'fall'),
#  (38, 'let'),
#  (39, 'History'),
#  (40, ';'),
#  (41, 'truth'),
#  (42, 'free'),
#  (43, 'The'),
#  (44, "'ll"),
#  (45, 'all'),
#  (46, 'we'),
#  (47, 'Our'),
#  (48, 'land'),
#  (49, 'our'),
#  (50, 'We')]

# %% [markdown]
# ## Task 2: Author Gender Classification
#
# Our next task will be to classify text based on the author's gender. We can find this under the 'htrc_gender' attribute found in each volume's metadata.
#
# We will create the training set using the existing volumes we have already seen in the previous example by searching the metadata fields for gender. We will then add the volumes with these attributes, as well as add the correct labels to our `y` vector. For this example, we will use 10 training samples for each class to show the example.

# %%
vols = []
y_2 = []

wordDictGender = {}
subjects = [history, poetry, scifi]
index = 0
male = 0
female = 0

for subject in subjects:
    for vol in subject.volumes():
        if male == 10 and female == 10:
            break
        try:
            if str(vol.metadata['htrc_gender'][0]) == 'male':
                if male < 10:
                    vols.append(vol)
                    tok_list = vol.tokenlist(pages=False)
                    tokens = tok_list.index.get_level_values('token')
                    for token in tokens:
                        if token not in wordDictGender.keys():
                            wordDictGender[token] = index
                            index += 1
                            
                    y_2.append(0)
                    male += 1
                    
            elif str(vol.metadata['htrc_gender'][0]) == 'female':
                if female < 10:
                    vols.append(vol)
                    tok_list = vol.tokenlist(pages=False)
                    tokens = tok_list.index.get_level_values('token')
                    
                    for token in tokens:
                        if token not in wordDictGender.keys():
                            wordDictGender[token] = index
                            index += 1
                    
                    y_2.append(1)
                    female += 1
        except:
            pass
    if male == 10 and female == 10:
        break
# Out:
# ERROR:root:Unexpected: there were 0 results for coo.31924029579814 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000010053274 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000042013833 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000046348185 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000046368365 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000085261075 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000092448210 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000111022061 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000115666806 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000115670873 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000116553128 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000117880595 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000117880603 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000122783305 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000122783313 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000122783339 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000122783354 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000122783677 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000122783685 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000122784311 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000122786431 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000122786449 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000122786480 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000122786498 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000122786530 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.39000000587258 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.39000005568071 instead of 1.
# ERROR:root:Unexpected: there were 0 results for loc.ark:/13960/t0cv57t9q instead of 1.
# ERROR:root:Unexpected: there were 0 results for loc.ark:/13960/t9862w21q instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015000580418 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015001351496 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015003456590 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015004164599 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015005194066 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015005642080 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015005944825 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015006973971 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015006973997 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015008458633 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015008554621 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015008574959 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015010338195 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015010758731 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015010924036 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015011284240 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015011358739 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015011358747 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015011889915 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015011911578 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015013973709 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015013977239 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015013977247 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015014155009 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015014493053 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015014518776 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015014651510 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015014952009 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015016319264 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015016755558 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015018609415 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015018613862 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015019137960 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015019989170 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015020865872 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015021460251 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015025243687 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015026671357 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015026671712 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015028574419 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015028774449 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015030331030 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015031730560 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015031730578 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015032094131 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015032742978 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015033533145 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015033668701 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015033671861 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015033870976 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015033871131 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015034314099 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015034564628 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015035321317 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015035426835 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015035762965 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015038926229 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015040088141 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015040611223 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015040623152 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015043358210 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015045993956 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015046413988 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015046492719 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015047728186 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015050928822 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015053426964 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015054120954 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015054408797 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015056264321 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015057653555 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015059729924 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015060071712 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015060108225 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015061302488 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015062730711 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015063389848 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015065455837 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015065458294 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015065458344 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015065819818 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015065819826 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015066113542 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015066382550 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015068949844 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015068949851 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015068949869 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015068949935 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015070692549 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015071440419 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015074906101 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015074916118 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015074916480 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015074916498 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015074916506 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015074916605 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015074916613 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015074916654 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015074916662 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015074916787 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015074916795 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015074916803 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015076675555 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015076675597 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015076676025 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015078215020 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015078262279 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015078265975 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015078265983 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015078265991 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015078669176 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079172857 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079627314 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079632728 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079632736 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079632744 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079632751 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079632769 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079633064 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079633072 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079905264 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.49015000040791 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.49015000040924 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.49015001451401 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.49015002465962 instead of 1.
# ERROR:root:Unexpected: there were 0 results for nc01.ark:/13960/t4pk1755w instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000008928474 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000009256347 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000009901643 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000022034724 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000024457644 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000045712050 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000060210135 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.$b137987 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.$b543502 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.$b66727 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106010640826 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106012088719 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020065972 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020065980 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020072358 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020072390 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020072416 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020072440 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020072457 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020072556 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020072572 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020343106 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020343163 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020343171 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020343189 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020343197 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020343213 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020343221 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020343239 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020343247 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020343254 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020343270 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020343296 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020403413 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020403421 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020403447 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020403454 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020403470 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020403496 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020403504 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.32106020403538 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b2843960 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b3109939 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b3340712 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b3478708 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b4232399 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b4373632 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b4373634 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b4373635 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b4373638 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b4373641 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b4373684 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b4446101 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b4447543 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b4447544 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b4447545 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uc1.b4919262 instead of 1.
# ERROR:root:Unexpected: there were 0 results for uiug.30112088206286 instead of 1.
# ERROR:root:Unexpected: there were 0 results for umn.319510013519320 instead of 1.
# ERROR:root:Unexpected: there were 0 results for umn.31951d000278888 instead of 1.
# ERROR:root:Unexpected: there were 0 results for umn.31951d00184926y instead of 1.
# ERROR:root:Unexpected: there were 0 results for umn.31951d01956099n instead of 1.
# ERROR:root:Unexpected: there were 0 results for umn.31951p005835558 instead of 1.
# ERROR:root:Unexpected: there were 0 results for umn.31951t000800439 instead of 1.
# ERROR:root:Unexpected: there were 0 results for umn.31951t000800447 instead of 1.
# ERROR:root:Unexpected: there were 0 results for umn.31951t00081341w instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89011046869 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89058306374 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89058306390 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89058306507 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89058306523 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89058306531 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89058306549 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89058306556 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89058306572 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89058306580 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89058308958 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89058315177 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89060438470 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89062263025 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89062944129 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89062944137 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89062946504 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89062946538 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89062946546 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89062947338 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89062949011 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89066001124 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89066001132 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89066001140 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89066001157 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89066001165 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89066001173 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89066001181 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89066001199 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89066080102 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89066407149 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89066407347 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89066450693 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89069272573 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89081070161 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89082382029 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89082382052 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89082485178 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89094321577 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89096332697 instead of 1.
# ERROR:root:Unexpected: there were 0 results for wu.89108658733 instead of 1.
# ERROR:root:Unexpected: there were 0 results for hvd.hx4351 instead of 1.
# ERROR:root:Unexpected: there were 0 results for iau.31858013698646 instead of 1.
# ERROR:root:Unexpected: there were 0 results for iau.31858028062101 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000001662869 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000001913064 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000001913072 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000004683136 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000004972505 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000007613858 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000021399302 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000046725903 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000048886851 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000087655415 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000095269225 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000099743076 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000100354632 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000102866518 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000107236527 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000117862049 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000117862189 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000122782828 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.30000122867397 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.32000001301490 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.32000001869082 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.39000002913148 instead of 1.
# ERROR:root:Unexpected: there were 0 results for inu.39000005874701 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015000520562 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015000567787 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015000657240 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015001542540 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015002263427 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015002577883 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015003453407 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015003755181 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015005009306 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015005791713 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015005885192 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015006946373 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015007036778 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015008279682 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015008279690 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015008435888 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015008943519 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015009337653 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015010376484 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015010415340 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015011230565 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015011290726 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015011685586 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015011703405 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015011730879 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015011916577 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015012337823 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015012871581 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015012899418 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015012976042 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015014518768 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015014747532 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015015886222 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015016981113 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015017010011 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015017436471 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015019057572 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015020812437 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015020831619 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015021460418 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015021460426 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015021560084 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015021642007 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015021953172 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015022283603 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015023467981 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015023471009 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015023471017 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015023733044 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015023954491 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015025041065 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015028415712 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015028747312 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015030912441 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015031023255 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015031023321 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015031239539 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015031702510 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015031730412 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015032031695 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015032296793 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015032647409 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015033527758 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015033527766 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015033527774 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015033527790 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015033534127 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015033534143 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015033536213 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015033642672 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015034442627 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015034618952 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015034909377 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015034912504 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015035009508 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015035730707 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015036860438 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015036929092 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015036929118 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015036938150 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015039741478 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015040628201 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015041007090 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015046336577 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015049728176 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015050245508 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015050290249 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015050299174 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015050488744 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015050499600 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015050543498 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015051314725 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015052661991 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015055203544 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015055333945 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015055798451 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015056652426 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015056815049 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015056883773 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015058207104 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015058209472 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015058330237 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015058392658 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015058396659 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015058396675 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015058707376 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015059115751 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015059706096 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015059964810 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015059965213 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015060048561 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015060073205 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015060077404 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015060588079 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015060851543 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015061526094 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015061931476 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015063261609 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015063285020 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015063348620 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015063656733 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064381810 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064381828 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064381836 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064381992 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064382016 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064382024 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064382081 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064382099 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064382131 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064382149 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064382156 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064382164 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064382172 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064382180 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064382198 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064382206 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064382214 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064382222 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064382230 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064700019 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064751251 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015064934030 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015065524608 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015065526900 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015065804802 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015065804950 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015066864433 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015070519924 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015070519932 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015072460804 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015072463386 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015072463394 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015072463410 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015072463428 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015072463477 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015072463493 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015073645296 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015073658463 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015074905509 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015074905707 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015076179517 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015077204215 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015077204249 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015077624297 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015078785261 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015078806414 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079621325 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079623099 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079623198 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079631894 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079632033 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015079632181 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015080237228 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015080237251 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015080874186 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39015082617104 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39076000033733 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39076002847270 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.39076002965775 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.49015000463688 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.49015000683095 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.49015002051374 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.49015002914233 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.49015002914407 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.49015002914415 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.49015002914555 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.49015003043636 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.49015003043651 instead of 1.
# ERROR:root:Unexpected: there were 0 results for mdp.49015003053940 instead of 1.
# ERROR:root:Unexpected: there were 0 results for nyp.33433081792958 instead of 1.
# ERROR:root:Unexpected: there were 0 results for nyp.33433112038561 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000010159279 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000012433513 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000013241353 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000021214738 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000025048810 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000027295533 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000029979233 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000044153458 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000050263523 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000050670321 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000056096750 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000057932347 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000058531037 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000060320735 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000060350824 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000064913681 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000065814741 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000065814758 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000065814826 instead of 1.
# ERROR:root:Unexpected: there were 0 results for pst.000067849451 instead of 1.

# %% [markdown]
# We can then take these volumes and create our bag of words matrix as we did in the previous example. Finally, we can run our LinearSVC model once again to show how well our model does.

# %%
import numpy as np

print("Generating bag of words matrix")
volCount = 20
dtm_gender = np.zeros((volCount, len(wordDictGender.keys())))

for i, vol in enumerate(vols):
    tok_list = vol.tokenlist(pages=False)
    counts = list(tok_list['count'])
    tokens = tok_list.index.get_level_values('token')
    
    for token, count in zip(tokens, counts):
        try:
            index = wordDictGender[token]
            dtm_gender[i, index] = count
        except:
            pass
        
X_2 = dtm_gender

print("Finished")
# Out:
# Generating bag of words matrix
# Finished

# %%
tfidf = TfidfTransformer()
out = tfidf.fit_transform(X_2, y_2)

model = LinearSVC()

score = cross_validation.cross_val_score(model, X_2, y_2, cv=10)
print(np.mean(score))
# Out:
# 0.85

# %%
model.fit(X_2, y_2)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
feats = np.argsort(model.coef_[0])[:50]
top_male = [(list(feats).index(wordDict[w]) + 1, w) for w in wordDict.keys() if wordDict[w] in feats]
sorted(top_male)
# Out:
# [(1, 'foul'),
#  (2, 'fascinated'),
#  (3, 'There’s'),
#  (4, 'colorless'),
#  (5, '..'),
#  (6, 'culmination'),
#  (7, 'conception'),
#  (8, 'cyclonic'),
#  (9, 'inﬂators'),
#  (10, 'greatest'),
#  (11, 'Physically'),
#  (12, 'imperceptibly'),
#  (13, 'Trained'),
#  (14, 'arbiters'),
#  (15, 'guard'),
#  (16, 'foreground'),
#  (17, 'atmospheric'),
#  (18, "'from"),
#  (19, 'nights'),
#  (20, 'darts'),
#  (21, 'more’n'),
#  (22, 'Slammer'),
#  (23, 'dojust'),
#  (24, 'blue-tinged'),
#  (25, 'Kung'),
#  (26, 'integrator’s'),
#  (27, 'faithful'),
#  (28, 'example'),
#  (29, 'mounted'),
#  (30, 'answers'),
#  (31, 'deceased'),
#  (32, 'astrogater’s'),
#  (33, 'kind'),
#  (34, 'difficulties'),
#  (35, 'Kumo'),
#  (36, "'it"),
#  (37, 'goggles'),
#  (38, 'learn'),
#  (39, 'braking'),
#  (40, 'articulate'),
#  (41, 'War'),
#  (42, 'juus'),
#  (43, 'doled'),
#  (44, 'febrile'),
#  (45, 'protracted'),
#  (46, 'grin'),
#  (47, '1946'),
#  (48, 'wavered'),
#  (49, 'instantaneously'),
#  (50, 'car—and')]

# %%
feats = np.argsort(model.coef_[0])[-50:]
top_female = [(list(feats).index(wordDict[w]) + 1, w) for w in wordDict.keys() if wordDict[w] in feats]
sorted(top_female, key=lambda tup: tup[0])
# Out:
# [(1, 'ache'),
#  (2, 'close'),
#  (3, 'laugh'),
#  (4, 'inﬂexible'),
#  (5, 'legends'),
#  (6, 'clarity'),
#  (7, 'grandfather—did'),
#  (8, 'audience'),
#  (9, 'Aika'),
#  (10, 'armed'),
#  (11, 'Zim'),
#  (12, 'does'),
#  (13, 'Shooting'),
#  (14, 'decipherable'),
#  (15, 'What'),
#  (16, 'Gailah'),
#  (17, 'boring'),
#  (18, 'close-up'),
#  (19, 'consultin’'),
#  (20, 'city'),
#  (21, 'coruscating'),
#  (22, 'drowsy'),
#  (23, 'cooking'),
#  (24, 'Graphic'),
#  (25, 'exhibition'),
#  (26, 'Gambler'),
#  (27, 'irrational'),
#  (28, 'contractors'),
#  (29, 'lighter'),
#  (30, 'Unhurt'),
#  (31, 'Sophocles'),
#  (32, 'chemistry'),
#  (33, 'REY'),
#  (34, 'Title'),
#  (35, 'leam'),
#  (36, 'body'),
#  (37, '213'),
#  (38, 'Sturgeon'),
#  (39, ')'),
#  (40, '!/hen'),
#  (41, 'five'),
#  (42, 'it—if'),
#  (43, 'war—of'),
#  (44, 'lava'),
#  (45, 'climax'),
#  (46, '...._'),
#  (47, '0-88355-l26-8'),
#  (48, '“have'),
#  (49, 'Physiology'),
#  (50, 'Phil—ﬁfteen')]

# %% [markdown]
# Congratulations! You've finished the tutorial. You now have the tools to run your own classification tasks with the HTRC library. Try using different models or adding more volumes to increase your accuracy scores for your model.
